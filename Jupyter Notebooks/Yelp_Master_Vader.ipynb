# %%
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.6/dist-packages (3.2.1)

# %%
import pandas as pd
import json
import numpy as np
import requests
from yelpkeys import (Client_ID, API_Key)
from pprint import pprint
import pydbgen
from pydbgen import pydbgen

# %%
business_data={"Business ID":[],
               "Business Name":[],
               "Business Alias":[],
               "City":[],
               "State":[],
               "ZipCode":[],
               "Lat":[],
               "Long":[],
               "Review Count":[],
               "Rating":[],
              }
review_data={"Business ID":[],
             "Review":[],
             "Compound":[]
            }

# %%
myDB=pydbgen.pydb()
city=[]
for cities in range(5):
    city.append(myDB.city_real())
city_yelp=pd.DataFrame(city)
city_yelp=city_yelp.rename(columns={0:"US Cities"})
city_yelp.head()
# Out:
#             US Cities
# 0             Pickett
# 1  North Belle Vernon
# 2          Bayou Meto
# 3                Bach
# 4           Bareville

# %%
api_key=API_Key
headers = {"Authorization": (f"Bearer {api_key}")}
url="https://api.yelp.com/v3/businesses/search?"
review_url="https://api.yelp.com/v3/businesses/"
categories="lawyers"
radius = 4000
counter = 1

# %%
for index, row in city_yelp.iterrows():
    random_city = row['US Cities']
    #print(f"{counter}: {random_city}")
    yelp_response2 = requests.get((f"{url}categories={categories}&location={random_city}&radius={radius}"), headers=headers).json()
    counter+=1
    #print(len(yelp_response2["businesses"]))
    for x in range(len(yelp_response2["businesses"])):
        try:
            business_data["Business ID"].append(yelp_response2["businesses"][x]["id"])
            business_data["Business Name"].append(yelp_response2["businesses"][x]["name"])
            business_data["Business Alias"].append(yelp_response2["businesses"][x]["alias"])
            business_data["City"].append(yelp_response2["businesses"][x]["location"]["city"])
            business_data["State"].append(yelp_response2["businesses"][x]["location"]["state"])
            business_data["ZipCode"].append(yelp_response2["businesses"][x]["location"]["zip_code"])
            business_data["Lat"].append(yelp_response2["businesses"][x]["coordinates"]["latitude"])
            business_data["Long"].append(yelp_response2["businesses"][x]["coordinates"]["longitude"])
            business_data["Review Count"].append(yelp_response2["businesses"][x]["review_count"])
            business_data["Rating"].append(yelp_response2["businesses"][x]["rating"])
        except: 
            print(f"     No dining locations found in {random_city}.")

# %%
graph_data=pd.DataFrame.from_dict(business_data, orient='columns')#, dtype=None, columns=None)
graph_data
# Out:
#                                 Business Alias             Business ID  \
# 0              vanderman-law-offices-charleroi  wcopdY2nMfIPp-8vaVt7cA
# 1             megan-a-kern-law-office-monessen  FAvqkDivhSe3rF84C_bttA
# 2                   wagner-law-group-atlanta-3  -bzmsu9yx6tRllegf8ob9g
# 3                the-angell-law-firm-atlanta-2  aymqigLmk5XkPgBuy33S4A
# 4                   the-fryer-law-firm-atlanta  mE1gsgG0Q1pQnlIrCKPDYg
# 5          partnership-title-company-atlanta-2  MCpLu1lCI37JMHYivHj-JQ
# 6         stottlemyer-and-associates-atlanta-2  Ycxth4mW6tMKCFSkteV2Yw
# 7   georgia-title-and-escrow-company-atlanta-3  GcjSIbC9fIDa6P25dj694A
# 8                kitchens-new-cleghorn-atlanta  JNaXzRqPnm7SXS2af8u1Vw
# 9                    kevin-patrick-law-atlanta  og25y5tHa-K5vVbJooEsyA
# 10                   pope-and-howard-atlanta-2  51CgLJgfhQF3nPAwVbVUwg
# 11            goldstein-and-hayes-pc-atlanta-3  yMSoDBcN_K-VKJ0xTA3Mzw
# 12                    chancoschiffer-atlanta-2  sNrtBDZtUPMy9VFuw4qcdA
# 13                the-awad-law-firm-pc-atlanta  84b8vy69g6X1r8oMSqGzuA
# 14         cummings-and-middlebrooks-atlanta-2  9mGXA0QliQFc-WKRsoogLQ
# 15                bader-law-firm-llc-atlanta-2  rnVOCBdKFlnNfC8DeWuMbQ
# 16                       the-cook-firm-atlanta  yB-7iZwmRP05Xl4PByqUhg
# 17                  kwartin-and-levine-atlanta  izDkFARq5kT5RP4nNLPEnQ
# 18                 the-bruner-law-firm-atlanta  7v_Nnd7hwS0fXkfC1zWsfw
# 19                        butler-tobin-atlanta  OPhea88XYJ3RHAMLY5o0AQ
# 20      naggiar-and-sarif-family-law-atlanta-2  02zeuD3X8n04OrvmuPGF4Q
# 21      law-office-of-perry-dean-ellis-atlanta  _OLH7zcIsuo4O-nhJt8muA
# 22                   smoker-and-gard-llp-leola  P6jm_Tk0wI3lv4X9VinzAA
#
#                      Business Name       City        Lat       Long  Rating  \
# 0            Vanderman Law Offices  Charleroi  40.135060 -79.894740     2.5
# 1          Megan A Kern Law Office   Monessen  40.159514 -79.871893     1.0
# 2                 Wagner Law Group    Atlanta  33.830289 -84.342668     5.0
# 3              The Angell Law Firm    Atlanta  33.848799 -84.365766     5.0
# 4               The Fryer Law Firm    Atlanta  33.825890 -84.353678     5.0
# 5        Partnership Title Company    Atlanta  33.834792 -84.366986     5.0
# 6         Stottlemyer & Associates    Atlanta  33.840427 -84.373802     5.0
# 7   Georgia Title & Escrow Company    Atlanta  33.853860 -84.378932     5.0
# 8            Kitchens New Cleghorn    Atlanta  33.836166 -84.370443     5.0
# 9                Kevin Patrick Law    Atlanta  33.832700 -84.368690     5.0
# 10                   Pope & Howard    Atlanta  33.846508 -84.356098     5.0
# 11           Goldstein & Hayes, PC    Atlanta  33.839555 -84.381276     5.0
# 12                  ChancoSchiffer    Atlanta  33.846710 -84.358240     5.0
# 13           The Awad Law Firm, PC    Atlanta  33.826521 -84.354147     4.0
# 14         Cummings & Middlebrooks    Atlanta  33.846760 -84.358332     5.0
# 15             Bader Law Firm, LLC    Atlanta  33.849856 -84.365740     3.5
# 16                   The Cook Firm    Atlanta  33.825533 -84.355575     5.0
# 17                Kwartin & Levine    Atlanta  33.831270 -84.339850     4.0
# 18             The Bruner Law Firm    Atlanta  33.846730 -84.358315     5.0
# 19                    Butler Tobin    Atlanta  33.825433 -84.355458     5.0
# 20      Naggiar & Sarif Family Law    Atlanta  33.844186 -84.370193     4.5
# 21  Law Office of Perry Dean Ellis    Atlanta  33.852236 -84.375384     5.0
# 22               Smoker & Gard Llp      Leola  40.089810 -76.178200     1.0
#
#     Review Count State ZipCode
# 0              3    PA   15022
# 1              1    PA   15062
# 2             13    GA   30329
# 3              6    GA   30326
# 4              5    GA   30324
# 5              3    GA   30305
# 6              3    GA   30305
# 7              4    GA   30305
# 8              3    GA   30305
# 9              3    GA   30305
# 10             3    GA   30326
# 11             3    GA   30305
# 12             3    GA   30326
# 13             5    GA   30324
# 14             3    GA   30326
# 15             7    GA   30326
# 16             3    GA   30324
# 17             5    GA   30329
# 18             2    GA   30326
# 19             2    GA   30324
# 20             6    GA   30305
# 21             2    GA   30309
# 22             1    PA   17540

# %%
for id in business_data["Business ID"]:
    yelp_response3 = requests.get((f"{review_url}{id}/reviews"), headers=headers).json()
    pprint(yelp_response3)
    for x in range(len(yelp_response3["reviews"])):
        try:
            review_data["Business ID"].append(yelp_response3["reviews"][x]["id"])
            review_data["Review"].append(yelp_response3["reviews"][x]["text"])
            

        except:
            print("skipping")

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
review_text = review_data["Review"]
dicty={"Text": [],
     "Compound": []}
for text in review_text:
  results = analyzer.polarity_scores(text)
  dicty["Compound"].append(results["compound"])
  dicty["Text"].append(text)

# %%
cp_df = pd.DataFrame(dicty)
cp_df
# Out:
#     Compound                                               Text
# 0     0.6136  I have used this firm for many issues over the...
# 1    -0.7906  Mr. Vanderman's misleading statements and fail...
# 2     0.0000  Mr. Vanderman  seems to be never is  in his of...
# 3     0.0000  Let's see here I paid her In  November a non r...
# 4     0.0000  I am the first-time home buyer. \nI am not fam...
# 5     0.4754  Bo was very helpful with my daughters first ho...
# 6     0.5719  Bo was such a pleasure to work with for the cl...
# 7     0.8020  Angell Law Firm is an excellent company they a...
# 8     0.8553  Working with Bryce and his team has been a ver...
# 9     0.3400  I'm only giving them a 4 star because I only h...
# 10    0.8268  We had to venture here to close on our house. ...
# 11    0.8000  We closed a few months ago and these Fryer fol...
# 12   -0.3103  After failing to review my loan docs beforehan...
# 13    0.6249  We use PTC for our real estate investment clos...
# 14    0.6369  I can't rate this closing attorney highly enou...
# 15    0.4754  John at Partnership Title Company was extremel...
# 16   -0.4168  Patrick and his entire team are extremely prof...
# 17    0.9304  Sarah and her team are the BEST in the busines...
# 18    0.9370  Absolutely amazing!!! Would recommend to anyon...
# 19    0.0772  I wish I found them sooner.  Unfortunately, du...
# 20    0.0000  What can you say about signing documents for y...
# 21    0.0000  Chris is the one to go with. I found Chris on ...
# 22   -0.5583  Divorce is never an easy situation. I understa...
# 23    0.6673  I have used them twice.  The first time, Jeff ...
# 24    0.8385  Need a GLBT friendly lawyer? Or just like know...
# 25   -0.0240  Kevin and his team were great to work with. It...
# 26    0.6540  I had nothing but the best experience with thi...
# 27    0.8122  Kevin is a great attorney who cares about his ...
# 28    0.7717  I made the best choice of picking a lawyer for...
# 29    0.7420  I've known Brad Dozier for several years perso...
# ..       ...                                                ...
# 32   -0.2960  My husband was killed in the line of duty in 2...
# 33    0.7378  Jimmy Goldstein has represented our family and...
# 34    0.7579  Mr. Josh Schiffer is an excellent attorney. We...
# 35    0.6486  This group is a true asset to the Atlanta law ...
# 36    0.4939  I consider Josh Schiffer a friend. We are alum...
# 37    0.0000  The Awad Law Firm, specifically Ibrahim Awad, ...
# 38   -0.5719  In his response he mentions spending "hours ca...
# 39   -0.5267  Attorney Awad is my go-to referral for any per...
# 40    0.9246  Will Cummings handled my case did a great job ...
# 41    0.8582  I would recommend this Law Firm to anyone, Tra...
# 42   -0.4215  The Picture is my Lawyer's Partner Tracy W Mid...
# 43    0.8655  Seth Bader and his team are highly knowledgeab...
# 44   -0.6562  Don't waste your time \nThey have hanged up on...
# 45   -0.2105  We try to get a lawyer for a case that is not ...
# 46    0.0000  The attorneys and those working with the Cook ...
# 47    0.8192  EXCELLENT\nI was referred to Mr Cook by a frie...
# 48    0.5719  Mr. Cook is an excellent attorney.  His extens...
# 49    0.4588  I engaged Alexa in a child support modificatio...
# 50    0.9381  Alexa Kwartin is an intelligent, compassionate...
# 51    0.8070  Alexa is absolutely wonderful - detailed, stra...
# 52    0.9152  Mr. Sam Bruner is an amazing family attorney. ...
# 53    0.1280  Sam. He got me my son. My wife and I had scour...
# 54    0.5106  Excellent attorneys who know their stuff and w...
# 55   -0.3412  I couldn't ask for a better attorney for my ca...
# 56   -0.0387  I don't know about Salvador's review.  Mine's ...
# 57    0.0000  They have a stellar reputation for a reason. I...
# 58    0.4767  I was referred to Danny Naggiar and was impres...
# 59    0.8347  Perry is superb! So on top of his game and att...
# 60    0.7003  We have had a great experience with Perry and ...
# 61    0.0818  I used Smoker and Co for a personal tax return...
#
# [62 rows x 2 columns]
